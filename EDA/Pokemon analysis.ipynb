# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Pokemon.csv',index_col = 0,encoding  = 'latin')

# %%
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# ...

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  151.00000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean   407.07947   64.211921   72.549669   68.225166   67.139073   66.019868
# std     99.74384   28.590117   26.596162   26.916704   28.534199   24.197926
# min    195.00000   10.000000    5.000000    5.000000   15.000000   20.000000
# 25%    320.00000   45.000000   51.000000   50.000000   45.000000   49.000000
# 50%    405.00000   60.000000   70.000000   65.000000   65.000000   65.000000
# 75%    490.00000   80.000000   90.000000   84.000000   87.500000   80.000000
# max    680.00000  250.000000  134.000000  180.000000  154.000000  125.000000
#
#             Speed       Stage
# count  151.000000  151.000000
# mean    68.933775    1.582781
# std     26.746880    0.676832
# min     15.000000    1.000000
# 25%     46.500000    1.000000
# 50%     70.000000    1.000000
# 75%     90.000000    2.000000
# ...

# %% [markdown]
# ### 1.no null values in numerical columns because count is same
# ### 2.mean and median in are far apart from eachother so it not a proper bell curve or normal distribution
# ### but other columns are almost same here all proper bell curve
# ### 3.mean and stddev are far apart from each other so they wil be a range will be high, flat curve, outlieers while others cols will be range will not be high and outlier will be less and curve wont be flat

# %%
sns.distplot(df['Total'],kde = True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
sns.pairplot(df,diag_kind = 'kde',kind = 'scatter',palette = 'husl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 sns.pairplot(df,hue = 'Type 2',diag_kind = 'kde',kind = 'scatter',palette = 'husl')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2130, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
# ...

# %%
df.dtypes
# Out:
# Name         object
# Type 1       object
# Type 2       object
# Total         int64
# HP            int64
# Attack        int64
# Defense       int64
# Sp. Atk       int64
# Sp. Def       int64
# Speed         int64
# Stage         int64
# Legendary      bool
# dtype: object

# %%
iris = sns.load_dataset('iris')
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# ...

# %%
sns.distplot(df['HP'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
sns.distplot(df['Attack'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Attack', ylabel='Density'>

# %%
sns.distplot(df['Attack'],kde = True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Attack', ylabel='Density'>

# %%
sns.jointplot(x= 'Attack',y='Defense',data = df,kind = 'scatter',hue='Type 2')

# %% [markdown]
# 1. water type are msot commo pokemons
# 2. we hv outliers as high defense in ground, ice and highest attack water and flying
# 3. most of the  50 - 100 attack and 50 - 100 defense

# %%
sns.jointplot(x= 'Attack',y='Defense',data = df,kind = 'kde',hue='Type 2')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 sns.jointplot(x= 'Attack',y='Defense',data = df,kind = 'kde',hue='Type 2')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2284, in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# ...

# %%
sns.relplot(data = df,x='HP',y='Sp. Atk',kind='scatter',hue='Legendary',col='Type 2',col_wrap=2)

# %%
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# ...

# %%
sns.stripplot(x='Total',y='Type 1',data=df)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Type 1'>

# %%
sns.swarmplot(x='Attack',y='Type 2',data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Type 2'>

# %%
sns.boxplot(x='Attack',y='Type 2',data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Type 2'>
