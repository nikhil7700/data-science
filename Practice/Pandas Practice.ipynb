# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1 = pd.read_excel('data.xlsx')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df[df['Embarked'] == 'S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
df[df['Age']>=22]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#df[:,:5] # throws an error
df.iloc[:,:2]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %%
data = {'name': ['Kunal', 'Ankit', 'Purva', 'Pranav', 'Sunil'], 
        'age': [42, 52, 36, 24, 73], 
        'TestScore_1': [4, 24, 31, 2, 3],
        'TestScore_2': [25, 94, 57, 62, 70]}
df2 = pd.DataFrame(data, columns = ['name', 'age', 'TestScore_1', 'TestScore_2'])
df2
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df2['age'].sum()
# Out:
# 227

# %%
df2['TestScore_1'].mean()
# Out:
# 12.8

# %%
df2['TestScore_1'].describe()
# Out:
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: TestScore_1, dtype: float64

# %%
df2['TestScore_1'].count()
# Out:
# 5

# %%
df2['TestScore_1'].min()
# Out:
# 2

# %%
df2['TestScore_1'].max()
# Out:
# 31

# %%
df2['TestScore_1'].median()
# Out:
# 4.0

# %%
df2['TestScore_1'].std()
# Out:
# 13.663820841916802

# %%
df2['TestScore_1'].std()
# Out:
# 13.663820841916802

# %%
df2['TestScore_1'].var()
# Out:
# 186.7

# %%
df2['TestScore_1'].skew()
# Out:
# 0.7433452457326751

# %%
df2['TestScore_1'].kurt()
# Out:
# -2.4673543738411547

# %%
df2.corr()
# Out:
#                   age  TestScore_1  TestScore_2
# age          1.000000    -0.105651     0.328852
# TestScore_1 -0.105651     1.000000     0.378039
# TestScore_2  0.328852     0.378039     1.000000

# %%
df2.cov()
# Out:
#                 age  TestScore_1  TestScore_2
# age          340.80       -26.65       151.20
# TestScore_1  -26.65       186.70       128.65
# TestScore_2  151.20       128.65       620.30

# %%
df2.boxplot(column = "age", by = "name" )
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='name'>

# %%
df3 = pd.DataFrame([('The Hobbit','J.R.R. Tolkien'),
    ('Robinson Crusoe','Daniel Defoe'),
    ('Moby-Dick','Herman Melville')])
df3.rename(columns={0 : 'title',1 : 'author'},inplace=True)

# %%
data_BM = pd.read_csv('bigmart_data.csv')
data_BM.dropna(how='any')
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sorted_data = data_BM.sort_values(by ='Outlet_Establishment_Year')

# %%
sorted_data[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4338           FDH21          NaN          Low Fat         0.031074
# 3689           FDD53          NaN          Low Fat         0.044008
# 1139           FDH26          NaN          Regular         0.034532
# 1138           FDM21          NaN          Low Fat         0.064052
# 3691           FDY36          NaN          Low Fat         0.016477
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 4338       Seafood  157.5604            OUT027                       1985
# 3689  Frozen Foods   43.7454            OUT027                       1985
# 1139        Canned  142.2496            OUT027                       1985
# 1138   Snack Foods  256.1646            OUT027                       1985
# 3691  Baking Goods   74.3380            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data_BM.sort_values(by = 'Outlet_Establishment_Year',ascending = False,inplace = True)
data_BM.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5371           FDC11       20.500          Low Fat         0.142370
# 398            FDY34       10.500          Regular         0.011027
# 4326           FDY10       17.600          Low Fat         0.049268
# 5833           FDV21       11.500               LF         0.171780
# 8421           FDA43       10.895          Low Fat         0.064939
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 5371          Starchy Foods   90.6172            OUT018
# 398             Snack Foods  166.4842            OUT018
# 4326            Snack Foods  113.0176            OUT018
# 5833            Snack Foods  126.0704            OUT018
# 8421  Fruits and Vegetables  194.1794            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5371                       2009      Medium               Tier 3
# 398                        2009      Medium               Tier 3
# ...

# %%
data_bm = pd.read_csv('bigmart_data.csv')
data_bm.dropna(how='any')
data_bm.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_bm.sort_values(by=['Outlet_Establishment_Year','Item_Outlet_Sales'],ascending = False)[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02        21.35          Low Fat         0.069103
# 2803           FDU51        20.20          Regular         0.096907
# 641            FDY51        12.50          Low Fat         0.081465
# 2282           NCX30        16.70          Low Fat         0.026729
# 2887           FDR25        17.00          Regular         0.140090
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 43       Canned  259.9278            OUT018                       2009
# 2803       Meat  175.5028            OUT018                       2009
# 641        Meat  220.7798            OUT018                       2009
# 2282  Household  248.4776            OUT018                       2009
# 2887     Canned  265.1884            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data_bm.sort_values(by = ['Item_Outlet_Sales','Outlet_Establishment_Year'] ,ascending = False)[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7188           NCE42          NaN          Low Fat         0.010551
# 5223           FDQ19          NaN          Regular         0.014296
# 1450           FDZ20          NaN          Low Fat         0.000000
# 4349           FDP33          NaN          Low Fat         0.088840
# 6541           FDI50          NaN          Regular         0.030693
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7188              Household  234.9958            OUT027
# 5223  Fruits and Vegetables  242.6512            OUT027
# 1450  Fruits and Vegetables  253.0356            OUT027
# 4349            Snack Foods  254.2672            OUT027
# 6541                 Canned  228.0352            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7188                       1985      Medium               Tier 3
# 5223                       1985      Medium               Tier 3
# ...

# %%
data_bm.sort_index(inplace =True)
data_bm.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
import numpy as np

# %%
df_ages = pd.DataFrame({'age': np.random.randint(21, 51, 8)})

# %%
df_ages.head()
# Out:
#    age
# 0   30
# 1   44
# 2   23
# 3   40
# 4   42

# %%
df_ages['age_bins'] = pd.cut(x = df_ages['age'],bins = [20,29,39,49])

# %%
df_ages.head()
# Out:
#    age  age_bins
# 0   30  (29, 39]
# 1   44  (39, 49]
# 2   23  (20, 29]
# 3   40  (39, 49]
# 4   42  (39, 49]

# %%
df_ages['age_bins'].unique()
# Out:
# [(29, 39], (39, 49], (20, 29]]
# Categories (3, interval[int64, right]): [(20, 29] < (29, 39] < (39, 49]]

# %%
df_ages['age_by_dacade'] = pd.cut(x = df_ages['age'],bins =[20,29,39,49], labels = ['20s','30s','40s',] )

# %%
df_ages
# Out:
#    age  age_bins age_by_dacade
# 0   30  (29, 39]           30s
# 1   44  (39, 49]           40s
# 2   23  (20, 29]           20s
# 3   40  (39, 49]           40s
# 4   42  (39, 49]           40s
# 5   27  (20, 29]           20s
# 6   36  (29, 39]           30s
# 7   49  (39, 49]           40s

# %%
data_bm
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data_bm.apply(lambda x:x)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data_bm.apply(lambda x:x[0])
# Out:
# Item_Identifier                          FDA15
# Item_Weight                                9.3
# Item_Fat_Content                       Low Fat
# Item_Visibility                       0.016047
# Item_Type                                Dairy
# Item_MRP                              249.8092
# Outlet_Identifier                       OUT049
# Outlet_Establishment_Year                 1999
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                     3735.138
# dtype: object

# %%
data_bm.apply(lambda x:x['Item_Fat_Content'], axis = 1)
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Length: 8523, dtype: object

# %%
def clip_price(price):
    if price>200:
        price = 200
    return price

# %%
data_bm['Item_MRP'].apply(lambda x:clip_price(x))[:5]
# Out:
# 0    200.0000
# 1     48.2692
# 2    141.6180
# 3    182.0950
# 4     53.8614
# Name: Item_MRP, dtype: float64

# %%
def label_encode(city):
    if city == 'Tier 1':
        label = 0
    elif city == 'Tier 2':
        label = 1
    else:
        label = 2
    return label

data_bm['Outlet_Location_Type'].apply(lambda x:label_encode(x))
# Out:
# 0       0
# 1       2
# 2       0
# 3       2
# 4       2
#        ..
# 8518    2
# 8519    1
# 8520    1
# 8521    2
# 8522    0
# Name: Outlet_Location_Type, Length: 8523, dtype: int64

# %%
price_by_item = data_bm.groupby('Item_Type')
price_by_item.first()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Baking Goods                    FDP36       10.395          Regular
# Breads                          FDO23       17.850          Low Fat
# Breakfast                       FDP49        9.000          Regular
# Canned                          FDC14       21.350          Regular
# Dairy                           FDA15        9.300          Low Fat
# Frozen Foods                    FDH17       16.200          Regular
# Fruits and Vegetables           FDX07       19.200          Regular
# Hard Drinks                     DRI11       11.650          Low Fat
# Health and Hygiene              NCB42       11.800          Low Fat
# Household                       NCD19        8.930          Low Fat
# Meat                            FDN15       17.500          Low Fat
# Others                          NCN07       18.500          Low Fat
# Seafood                         FDG33       10.395          Regular
# ...

# %%
price_by_item['Item_MRP'].mean()
# Out:
# Item_Type
# Baking Goods             126.380766
# Breads                   140.952669
# Breakfast                141.788151
# Canned                   139.763832
# Dairy                    148.499208
# Frozen Foods             138.503366
# Fruits and Vegetables    144.581235
# Hard Drinks              137.077928
# Health and Hygiene       130.818921
# Household                149.424753
# Meat                     139.882032
# Others                   132.851430
# Seafood                  141.841719
# Snack Foods              146.194934
# Soft Drinks              131.492506
# Starchy Foods            147.838023
# Name: Item_MRP, dtype: float64

# %%
mean_price_by_item.first()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 mean_price_by_item.first()
#
# TypeError: first() missing 1 required positional argument: 'offset'

# %%
multiple_groups = data_bm.groupby(['Item_Type','Item_Fat_Content'])
multiple_groups.first()
# Out:
#                                Item_Identifier  Item_Weight  Item_Visibility  \
# Item_Type     Item_Fat_Content
# Baking Goods  LF                         FDP24       20.600         0.083133
#               Low Fat                    FDC37       11.100         0.057557
#               Regular                    FDP36       10.395         0.000000
#               low fat                    FDK48        7.445         0.000000
#               reg                        FDF24       15.500         0.025514
# ...                                        ...          ...              ...
# Starchy Foods LF                         FDB11       16.000         0.060797
#               Low Fat                    FDH35       18.250         0.000000
#               Regular                    FDB35       12.300         0.064750
#               low fat                    FDE47       14.150         0.037877
#               reg                        FDF11       10.195         0.017703
#
# ...

# %%
pd.crosstab(data_bm['Outlet_Size'],data_bm['Outlet_Location_Type'],margins =True)
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3   All
# Outlet_Size
# High                       0       0     932   932
# Medium                   930       0    1863  2793
# Small                   1458     930       0  2388
# All                     2388     930    2795  6113

# %%
pd.pivot_table(data_bm,index=['Outlet_Establishment_Year'],values  = 'Item_Outlet_Sales')
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1985                             2483.677474
# 1987                             2298.995256
# 1997                             2277.844267
# 1998                              339.351662
# 1999                             2348.354635
# 2002                             2192.384798
# 2004                             2438.841866
# 2007                             2340.675263
# 2009                             1995.498739

# %%
pd.pivot_table(data_bm,index=['Outlet_Establishment_Year','Outlet_Size'],values  = 'Item_Outlet_Sales',aggfunc=[np.mean,np.median,min,max,np.std])
# Out:
#                                                    mean            median  \
#                                       Item_Outlet_Sales Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Size
# 1985                      Medium            3694.038558         3364.9532
#                           Small              340.329723          265.3213
# 1987                      High              2298.995256         2050.6640
# 1997                      Small             2277.844267         1945.8005
# 1999                      Medium            2348.354635         1966.1074
# 2004                      Small             2438.841866         2109.2544
# 2009                      Medium            1995.498739         1655.1788
#
#                                                     min               max  \
#                                       Item_Outlet_Sales Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Size
# 1985                      Medium               241.6854        13086.9648
# ...
