# %%
import pandas as pd

# %%
df = pd.read_pickle('historical_nav.pkl')

# %%
df["data"]
# Out:
# 0        [{'date': '23-01-2023', 'nav': '108.98030'}, {...
# 1        [{'date': '23-01-2023', 'nav': '113.92040'}, {...
# 2        [{'date': '23-01-2023', 'nav': '111.38510'}, {...
# 3        [{'date': '23-01-2023', 'nav': '163.36420'}, {...
# 4        [{'date': '23-01-2023', 'nav': '110.77260'}, {...
#                                ...
# 12355    [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# 12356    [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# 12357    [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# 12358    [{'date': '23-01-2023', 'nav': '10.08080'}, {'...
# 12359    [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# Name: data, Length: 12360, dtype: object

# %%
navs_data = {}
for index,row in df.iterrows():
    nav_data = {}
    for data in row["data"]:
        nav_data[data["date"]] = data["nav"]
        
    navs_data[row["scheme_code"]] = nav_data
#print(nav_data)

# %%
print(navs_data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df2 = pd.DataFrame(navs_data)
df2.head()
# Out:
#                119551     119552     119553     108272     110282     108274  \
# 23-01-2023  108.98030  113.92040  111.38510  163.36420  110.77260  108.41360
# 20-01-2023  108.93350  113.87150  111.33720  163.29870  110.72820  108.37010
# 19-01-2023  108.95780  113.89690  111.36210  163.33670  110.75400  108.39530
# 18-01-2023  108.92900  113.86680  111.33260  163.29510  110.72580  108.36770
# 17-01-2023  108.90980  113.84670  111.31310  163.26790  110.70740  108.34970
#
#                110490     106157     108273     103176  ...    150965  \
# 23-01-2023  110.63200  111.17090  305.58180  458.71760  ...  10.08560
# 20-01-2023  110.58760  111.12640  305.45930  458.53360  ...  10.08110
# 19-01-2023  110.61330  111.15220  305.53030  458.64020  ...  10.09190
# 18-01-2023  110.58510  111.12390  305.45250  458.52340  ...  10.09080
# 17-01-2023  110.56680  111.10540  305.40170  458.44720  ...  10.08330
#
#               150970    150963    150966    150964    150967    150968  \
# ...

# %%
df2.to_pickle('historical_nav_final.pkl')

# %%
for index,row in df.iterrows():
    print(row['scheme_code'])
# Out:
# 119551
# 119552
# 119553
# 108272
# 110282
# 108274
# 110490
# 106157
# 108273
# 103176
# 119550
# 128952
# 120437
# 120438
# 120439
# 120436
# 128953
# 117447
# 117446
# 117449
# 117448
# 148629
# 148628
# 148630
# 148625
# 148626
# 148627
# 150505
# 150507
# 150503
# 150504
# 124175
# 124178
# 124182
# 124176
# 124177
# 124183
# 124172
# 124174
# 124173
# 124180
# 124181
# 124179
# 140286
# 140288
# 140291
# 140293
# 140290
# 140283
# 140284
# 140294
# 140292
# 140289
# 129008
# 129006
# 129009
# 129007
# 128628
# 128629
# 128627
# 128626
# 151108
# 151107
# 151106
# 151109
# 151102
# 151104
# 151105
# 151103
# 112343
# 112344
# 130897
# 120257
# 120256
# 120258
# 120255
# 130950
# 131148
# 112342
# 116174
# 131147
# 113247
# 113242
# 113243
# 121936
# 127471
# 121934
# 121279
# 121281
# 121935
# 121938
# 121933
# 127470
# 121931
# 121280
# 121282
# 121932
# 121937
# 118234
# 120444
# 120443
# 120445
# 118232
# 118233
# 148534
# 148536
# 148535
# 148533
# 123688
# 123858
# 123859
# ...

# %%
df
# Out:
#        scheme_code                                               data
# 0           119551  [{'date': '23-01-2023', 'nav': '108.98030'}, {...
# 1           119552  [{'date': '23-01-2023', 'nav': '113.92040'}, {...
# 2           119553  [{'date': '23-01-2023', 'nav': '111.38510'}, {...
# 3           108272  [{'date': '23-01-2023', 'nav': '163.36420'}, {...
# 4           110282  [{'date': '23-01-2023', 'nav': '110.77260'}, {...
# ...            ...                                                ...
# 12355       150967  [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# 12356       150968  [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# 12357       150971  [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
# 12358       150969  [{'date': '23-01-2023', 'nav': '10.08080'}, {'...
# 12359       150972  [{'date': '23-01-2023', 'nav': '10.08090'}, {'...
#
# [12360 rows x 2 columns]
