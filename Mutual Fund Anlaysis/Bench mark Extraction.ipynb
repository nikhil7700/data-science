# %%
import pandas as pd

# %%
import datetime as dt

# %%
df = pd.read_pickle('historical_nav_final.pkl')

# %%
bench_mark = pd.read_csv("nifty_5 yr_option_data.csv")

# %%
bench_mark
# Out:
#             Date      Open      High       Low     Close     Volume  \
# 0     2017-11-01  10390.35  10451.65  10383.05  10440.50  268270466
# 1     2017-11-02  10440.50  10453.00  10412.55  10423.80  207735021
# 2     2017-11-03  10461.55  10461.70  10403.60  10452.50  206101238
# 3     2017-11-06  10431.75  10490.45  10413.75  10451.80  199559409
# 4     2017-11-07  10477.15  10485.75  10340.80  10350.15  295830692
# ...          ...       ...       ...       ...       ...        ...
# 3626  2022-12-23  17977.65  18050.45  17779.50  17806.80  221454773
# 3627  2022-12-26  17830.40  18084.10  17774.25  18014.60  176652342
# 3628  2022-12-27  18089.80  18149.25  17967.45  18132.30  214257094
# 3629  2022-12-28  18084.75  18173.10  18068.35  18122.50  193873167
# 3630  2022-12-29  18045.70  18229.70  17992.80  18191.00  281052828
#
#           Turnover
# 0     1.420621e+11
# 1     1.077963e+11
# 2     1.007083e+11
# 3     1.023176e+11
# 4     1.618246e+11
# ...            ...
# ...

# %%
Nifty_final_extraction = df

# %%
#df.to_csv("test.csv")

# %%
Nifty_final_extraction
# Out:
#                119551     119552     119553     108272     110282     108274  \
# 23-01-2023  108.98030  113.92040  111.38510  163.36420  110.77260  108.41360
# 20-01-2023  108.93350  113.87150  111.33720  163.29870  110.72820  108.37010
# 19-01-2023  108.95780  113.89690  111.36210  163.33670  110.75400  108.39530
# 18-01-2023  108.92900  113.86680  111.33260  163.29510  110.72580  108.36770
# 17-01-2023  108.90980  113.84670  111.31310  163.26790  110.70740  108.34970
# ...               ...        ...        ...        ...        ...        ...
# 26-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 19-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 12-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 05-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 16-11-2019        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df2 = pd.read_csv('scheme_details.csv')

# %%
#df2

# %%
#3idf_df = df2[df2['scheme_category']=='IDF'

# %%
#df2[(df2['scheme_category']=='IDF')]['scheme_type'].nunique()

# %%
#idf_df

# %%
Niftyindex = df2[(df2['scheme_name'].str.contains('Nifty 50')) & (df2['scheme_name'].str.contains('Index'))]
Niftyindex
# Out:
#       Unnamed: 0                         fund_house         scheme_type  \
# 3309        3309                   IIFL Mutual Fund  Open Ended Schemes
# 3310        3310                   IIFL Mutual Fund  Open Ended Schemes
# 3311        3311                   IIFL Mutual Fund  Open Ended Schemes
# 3312        3312                   IIFL Mutual Fund  Open Ended Schemes
# 6430        6430  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# ...          ...                                ...                 ...
# 6923        6923                 Taurus Mutual Fund  Open Ended Schemes
# 6930        6930                    UTI Mutual Fund  Open Ended Schemes
# 6931        6931                    UTI Mutual Fund  Open Ended Schemes
# 6932        6932                    UTI Mutual Fund  Open Ended Schemes
# 6933        6933                    UTI Mutual Fund  Open Ended Schemes
#
#                  scheme_category  scheme_code  \
# 3309        Equity Scheme - ELSS       151165
# ...

# %%
Niftyindex[(Niftyindex['scheme_name'].str.contains('DSP'))]
# Out:
#       Unnamed: 0       fund_house         scheme_type  \
# 6494        6494  DSP Mutual Fund  Open Ended Schemes
# 6495        6495  DSP Mutual Fund  Open Ended Schemes
# 6496        6496  DSP Mutual Fund  Open Ended Schemes
# 6497        6497  DSP Mutual Fund  Open Ended Schemes
# 6498        6498  DSP Mutual Fund  Open Ended Schemes
# 6499        6499  DSP Mutual Fund  Open Ended Schemes
# 6500        6500  DSP Mutual Fund  Open Ended Schemes
# 6501        6501  DSP Mutual Fund  Open Ended Schemes
#
#                  scheme_category  scheme_code  \
# 6494  Other Scheme - Index Funds       141877
# 6495  Other Scheme - Index Funds       141878
# 6496  Other Scheme - Index Funds       141875
# 6497  Other Scheme - Index Funds       141876
# 6498  Other Scheme - Index Funds       146376
# 6499  Other Scheme - Index Funds       146377
# 6500  Other Scheme - Index Funds       146379
# 6501  Other Scheme - Index Funds       146378
#
# ...

# %%
Niftyindex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 3309 to 6933
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       68 non-null     int64
#  1   fund_house       68 non-null     object
#  2   scheme_type      68 non-null     object
#  3   scheme_category  68 non-null     object
#  4   scheme_code      68 non-null     int64
#  5   scheme_name      68 non-null     object
#  6   date             68 non-null     object
#  7   nav              68 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.8+ KB

# %%
Niftyindex['date'] = pd.to_datetime(Niftyindex['date'],format='%Y-%m-%d')
Niftyindex
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\4019204270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Niftyindex['date'] = pd.to_datetime(Niftyindex['date'],format='%Y-%m-%d')
#       Unnamed: 0                         fund_house         scheme_type  \
# 3309        3309                   IIFL Mutual Fund  Open Ended Schemes
# 3310        3310                   IIFL Mutual Fund  Open Ended Schemes
# 3311        3311                   IIFL Mutual Fund  Open Ended Schemes
# 3312        3312                   IIFL Mutual Fund  Open Ended Schemes
# 6430        6430  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# ...          ...                                ...                 ...
# ...

# %%
Niftyindex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 3309 to 6933
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       68 non-null     int64
#  1   fund_house       68 non-null     object
#  2   scheme_type      68 non-null     object
#  3   scheme_category  68 non-null     object
#  4   scheme_code      68 non-null     int64
#  5   scheme_name      68 non-null     object
#  6   date             68 non-null     object
#  7   nav              68 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.8+ KB

# %%
Niftyindex['date'] = Niftyindex['date'].dt.date
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\175176234.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Niftyindex['date'] = Niftyindex['date'].dt.date

# %%
Niftyindex[Niftyindex['date'] < dt.date(2023,1,1)]
# Out:
#       Unnamed: 0                         fund_house         scheme_type  \
# 6430        6430  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# 6431        6431  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# 6432        6432  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# 6433        6433  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# 6434        6434  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# ...          ...                                ...                 ...
# 6923        6923                 Taurus Mutual Fund  Open Ended Schemes
# 6930        6930                    UTI Mutual Fund  Open Ended Schemes
# 6931        6931                    UTI Mutual Fund  Open Ended Schemes
# 6932        6932                    UTI Mutual Fund  Open Ended Schemes
# 6933        6933                    UTI Mutual Fund  Open Ended Schemes
#
#                  scheme_category  scheme_code  \
# 6430  Other Scheme - Index Funds       148962
# ...

# %%
print(Niftyindex['scheme_name'],Niftyindex['date'])
# Out:
# 3309    IIFL ELSS Nifty 50 Tax Saver Index Fund - Dire...
# 3310    IIFL ELSS Nifty 50 Tax Saver Index Fund - Dire...
# 3311    IIFL ELSS Nifty 50 Tax Saver Index Fund - Regu...
# 3312    IIFL ELSS Nifty 50 Tax Saver Index Fund - Regu...
# 6430    Aditya Birla Sun Life Nifty 50 Equal Weight In...
#                               ...
# 6923    Taurus Nifty 50 Index Fund - Regular Plan - Pa...
# 6930         UTI Nifty 50 Index Fund - Direct Plan - IDCW
# 6931      UTI Nifty 50 Index Fund - Growth Option- Direct
# 6932    UTI Nifty 50 Index Fund - Regular Plan - Growt...
# 6933        UTI Nifty 50 Index Fund - Regular Plan - IDCW
# Name: scheme_name, Length: 68, dtype: object 3309    02-01-2023
# 3310    02-01-2023
# 3311    02-01-2023
# 3312    02-01-2023
# 6430    10-06-2021
#            ...
# 6923    21-06-2010
# 6930    02-01-2013
# 6931    02-01-2013
# 6932    03-04-2006
# 6933    03-04-2006
# Name: date, Length: 68, dtype: object

# %%
Niftyindexdaily = Niftyindex[(Niftyindex['scheme_name'].str.contains('Nifty 50')) & (Niftyindex['scheme_name'].str.contains('Index'))]

# %%
fund_house = Niftyindex['fund_house'].drop_duplicates()
scheme_code = Niftyindex['scheme_code'].drop_duplicates()

dict = {i:k for i,k in zip(scheme_code,fund_house)}
print(dict)

# cols = Nifty_final_extraction.columns
# for col in cols:
#     try:
#         if col in dict.keys():
#             replace logic 
#         else:
#             keep col as it is
#     except:
# Out:
# {151165: 'IIFL Mutual Fund', 151166: 'Aditya Birla Sun Life Mutual Fund', 151164: 'Axis Mutual Fund', 151167: 'DSP Mutual Fund', 148962: 'Edelweiss Mutual Fund', 148963: 'Franklin Templeton Mutual Fund', 148965: 'ICICI Prudential Mutual Fund', 148964: 'IDFC Mutual Fund', 119648: 'Kotak Mahindra Mutual Fund', 101314: 'LIC Mutual Fund', 119649: 'Motilal Oswal Mutual Fund', 101313: 'Navi Mutual Fund', 149373: 'Nippon India Mutual Fund', 149374: 'Tata Mutual Fund', 149371: 'Taurus Mutual Fund', 149372: 'UTI Mutual Fund'}

# %%
nifty_schemecode = [i for i in Niftyindex['scheme_code']]
print(len(nifty_schemecode))
Niftyindex['fund_house'].nunique()
# Out:
# 68
# 16

# %%
cols = Nifty_final_extraction.columns.tolist()
drop_col = [col for col in cols if col not in nifty_schemecode]
#print(drop_col)

Nifty_final_extraction = Nifty_final_extraction.drop(drop_col, axis=1)
Nifty_final_extraction
# Out:
#               151165    151166    151164    151167    148962    148963  \
# 23-01-2023   9.98900   9.98900   9.98720   9.98720  11.74900  11.74890
# 20-01-2023   9.93950   9.93950   9.93790   9.93790  11.69560  11.69550
# 19-01-2023   9.98360   9.98360   9.98200   9.98200  11.77380  11.77360
# 18-01-2023  10.01390  10.01390  10.01240  10.01240  11.80670  11.80660
# 17-01-2023   9.95340   9.95340   9.95190   9.95190  11.74970  11.74960
# ...              ...       ...       ...       ...       ...       ...
# 26-01-2019       NaN       NaN       NaN       NaN       NaN       NaN
# 19-01-2019       NaN       NaN       NaN       NaN       NaN       NaN
# 12-01-2019       NaN       NaN       NaN       NaN       NaN       NaN
# 05-01-2019       NaN       NaN       NaN       NaN       NaN       NaN
# 16-11-2019       NaN       NaN       NaN       NaN       NaN       NaN
#
#               148965    148964     119648     101314  ...     119288  \
# ...

# %%
Nifty_final_extraction.index = pd.to_datetime(Nifty_final_extraction.index)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\132203324.py:1: UserWarning: Parsing '23-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   Nifty_final_extraction.index = pd.to_datetime(Nifty_final_extraction.index)
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\132203324.py:1: UserWarning: Parsing '20-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   Nifty_final_extraction.index = pd.to_datetime(Nifty_final_extraction.index)
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\132203324.py:1: UserWarning: Parsing '19-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   Nifty_final_extraction.index = pd.to_datetime(Nifty_final_extraction.index)
# ...

# %%
Nifty_final_extraction.index = Nifty_final_extraction.index.date
Nifty_final_extraction
# Out:
#               151165    151166    151164    151167    148962    148963  \
# 2023-01-23   9.98900   9.98900   9.98720   9.98720  11.74900  11.74890
# 2023-01-20   9.93950   9.93950   9.93790   9.93790  11.69560  11.69550
# 2023-01-19   9.98360   9.98360   9.98200   9.98200  11.77380  11.77360
# 2023-01-18  10.01390  10.01390  10.01240  10.01240  11.80670  11.80660
# 2023-01-17   9.95340   9.95340   9.95190   9.95190  11.74970  11.74960
# ...              ...       ...       ...       ...       ...       ...
# 2019-01-26       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-01-19       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-12-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-05-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-11-16       NaN       NaN       NaN       NaN       NaN       NaN
#
#               148965    148964     119648     101314  ...     119288  \
# ...

# %%
Nifty_final_extraction = Nifty_final_extraction[Nifty_final_extraction.index > dt.date(2017,1,1)]
Nifty_final_extraction
# Out:
#               151165    151166    151164    151167    148962    148963  \
# 2023-01-23   9.98900   9.98900   9.98720   9.98720  11.74900  11.74890
# 2023-01-20   9.93950   9.93950   9.93790   9.93790  11.69560  11.69550
# 2023-01-19   9.98360   9.98360   9.98200   9.98200  11.77380  11.77360
# 2023-01-18  10.01390  10.01390  10.01240  10.01240  11.80670  11.80660
# 2023-01-17   9.95340   9.95340   9.95190   9.95190  11.74970  11.74960
# ...              ...       ...       ...       ...       ...       ...
# 2019-01-26       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-01-19       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-12-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-05-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-11-16       NaN       NaN       NaN       NaN       NaN       NaN
#
#               148965    148964     119648     101314  ...     119288  \
# ...

# %%
Nifty_final_extraction = Nifty_final_extraction[Nifty_final_extraction.index < dt.date(2023,1,1)]
Nifty_final_extraction
# Out:
#            151165 151166 151164 151167    148962    148963    148965  \
# 2022-12-30    NaN    NaN    NaN    NaN  11.72930  11.72920  11.61150
# 2022-12-29    NaN    NaN    NaN    NaN  11.75830  11.75810  11.64040
# 2022-12-28    NaN    NaN    NaN    NaN  11.72520  11.72500  11.60790
# 2022-12-27    NaN    NaN    NaN    NaN  11.72720  11.72710  11.61010
# 2022-12-26    NaN    NaN    NaN    NaN  11.62840  11.62830  11.51250
# ...           ...    ...    ...    ...       ...       ...       ...
# 2019-01-26    NaN    NaN    NaN    NaN       NaN       NaN       NaN
# 2019-01-19    NaN    NaN    NaN    NaN       NaN       NaN       NaN
# 2019-12-01    NaN    NaN    NaN    NaN       NaN       NaN       NaN
# 2019-05-01    NaN    NaN    NaN    NaN       NaN       NaN       NaN
# 2019-11-16    NaN    NaN    NaN    NaN       NaN       NaN       NaN
#
#               148964     119648     101314  ...     119288     101659  \
# ...

# %%
dropable = [151165,151166,151167,151164]

# %%
Nifty_final_extraction.drop(dropable,axis=1,inplace = True)
Nifty_final_extraction.shape
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\2815755682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nifty_final_extraction.drop(dropable,axis=1,inplace = True)
# (2169, 64)

# %%
Nifty_final_extraction.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 Nifty_final_extraction.sort_values()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
Nifty_final_extraction.reset_index(inplace=True)
Nifty_final_extraction.rename(columns={'index': 'index_col'}, inplace=True)
Nifty_final_extraction
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\1936689357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nifty_final_extraction.rename(columns={'index': 'index_col'}, inplace=True)
#        index_col    148962    148963    148965    148964     119648  \
# 0     2022-12-30  11.72930  11.72920  11.61150  11.61150  182.69900
# 1     2022-12-29  11.75830  11.75810  11.64040  11.64040  183.56610
# 2     2022-12-28  11.72520  11.72500  11.60790  11.60790  182.87850
# 3     2022-12-27  11.72720  11.72710  11.61010  11.61010  182.97980
# 4     2022-12-26  11.62840  11.62830  11.51250  11.51250  181.79480
# ...          ...       ...       ...       ...       ...        ...
# 2164  2019-01-26       NaN       NaN       NaN       NaN        NaN
# ...

# %%
Nifty_final_extraction.sort_values(by='index_col',inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\517243390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nifty_final_extraction.sort_values(by='index_col',inplace = True)

# %%
Nifty_final_extraction
# Out:
#        index_col    148962    148963    148965    148964     119648  \
# 1431  2017-01-02       NaN       NaN       NaN       NaN   85.40630
# 1413  2017-01-03       NaN       NaN       NaN       NaN   87.65020
# 1464  2017-01-04       NaN       NaN       NaN       NaN        NaN
# 1526  2017-01-05       NaN       NaN       NaN       NaN        NaN
# 1353  2017-01-06       NaN       NaN       NaN       NaN   94.22180
# ...          ...       ...       ...       ...       ...        ...
# 3     2022-12-27  11.72720  11.72710  11.61010  11.61010  182.97980
# 2     2022-12-28  11.72520  11.72500  11.60790  11.60790  182.87850
# 1     2022-12-29  11.75830  11.75810  11.64040  11.64040  183.56610
# 0     2022-12-30  11.72930  11.72920  11.61150  11.61150  182.69900
# 1454  2022-12-31       NaN       NaN       NaN       NaN        NaN
#
#          101314    119649    101313    149373  ...     119288     101659  \
# 1431   85.34590  12.14120  12.01410       NaN  ...   54.41580   51.84040
# ...

# %%
Nifty_final_extraction.set_index('index_col', inplace=True)

# %%
Nifty_final_extraction
# Out:
#               148962    148963    148965    148964     119648     101314  \
# index_col
# 2017-01-02       NaN       NaN       NaN       NaN   85.40630   85.34590
# 2017-01-03       NaN       NaN       NaN       NaN   87.65020   87.56810
# 2017-01-04       NaN       NaN       NaN       NaN        NaN        NaN
# 2017-01-05       NaN       NaN       NaN       NaN        NaN        NaN
# 2017-01-06       NaN       NaN       NaN       NaN   94.22180   94.06230
# ...              ...       ...       ...       ...        ...        ...
# 2022-12-27  11.72720  11.72710  11.61010  11.61010  182.97980  180.35610
# 2022-12-28  11.72520  11.72500  11.60790  11.60790  182.87850  180.25490
# 2022-12-29  11.75830  11.75810  11.64040  11.64040  183.56610  180.93130
# 2022-12-30  11.72930  11.72920  11.61150  11.61150  182.69900  180.07510
# 2022-12-31       NaN       NaN       NaN       NaN        NaN        NaN
#
#               119649    101313    149373    149374  ...     119288     101659  \
# ...

# %%
Niftyindex
# Out:
#       Unnamed: 0                         fund_house         scheme_type  \
# 3309        3309                   IIFL Mutual Fund  Open Ended Schemes
# 3310        3310                   IIFL Mutual Fund  Open Ended Schemes
# 3311        3311                   IIFL Mutual Fund  Open Ended Schemes
# 3312        3312                   IIFL Mutual Fund  Open Ended Schemes
# 6430        6430  Aditya Birla Sun Life Mutual Fund  Open Ended Schemes
# ...          ...                                ...                 ...
# 6923        6923                 Taurus Mutual Fund  Open Ended Schemes
# 6930        6930                    UTI Mutual Fund  Open Ended Schemes
# 6931        6931                    UTI Mutual Fund  Open Ended Schemes
# 6932        6932                    UTI Mutual Fund  Open Ended Schemes
# 6933        6933                    UTI Mutual Fund  Open Ended Schemes
#
#                  scheme_category  scheme_code  \
# 3309        Equity Scheme - ELSS       151165
# ...

# %%
scheme_code = [i for i in Niftyindex['scheme_code']]
fund_h = [i for i in Niftyindex['fund_house']]
print(len(scheme_code),len(fund_h))
mapping = {i:j for i,j in zip(scheme_code,fund_h)}
mapping
# Out:
# 68 68
# {151165: 'IIFL Mutual Fund',
#  151166: 'IIFL Mutual Fund',
#  151164: 'IIFL Mutual Fund',
#  151167: 'IIFL Mutual Fund',
#  148962: 'Aditya Birla Sun Life Mutual Fund',
#  148963: 'Aditya Birla Sun Life Mutual Fund',
#  148965: 'Aditya Birla Sun Life Mutual Fund',
#  148964: 'Aditya Birla Sun Life Mutual Fund',
#  119648: 'Aditya Birla Sun Life Mutual Fund',
#  101314: 'Aditya Birla Sun Life Mutual Fund',
#  119649: 'Aditya Birla Sun Life Mutual Fund',
#  101313: 'Aditya Birla Sun Life Mutual Fund',
#  149373: 'Axis Mutual Fund',
#  149374: 'Axis Mutual Fund',
#  149371: 'Axis Mutual Fund',
#  149372: 'Axis Mutual Fund',
#  141877: 'DSP Mutual Fund',
#  141878: 'DSP Mutual Fund',
#  141875: 'DSP Mutual Fund',
#  141876: 'DSP Mutual Fund',
#  146376: 'DSP Mutual Fund',
#  146377: 'DSP Mutual Fund',
#  146379: 'DSP Mutual Fund',
#  146378: 'DSP Mutual Fund',
#  149250: 'Edelweiss Mutual Fund',
#  149251: 'Edelweiss Mutual Fund',
#  149252: 'Edelweiss Mutual Fund',
# ...

# %%
Nifty_final_extraction.rename(columns=mapping,inplace=True)
Nifty_final_extraction
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15548\1676530478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nifty_final_extraction.rename(columns=mapping,inplace=True)
#            Aditya Birla Sun Life Mutual Fund  \
# index_col
# 2017-01-02                               NaN
# 2017-01-03                               NaN
# 2017-01-04                               NaN
# 2017-01-05                               NaN
# 2017-01-06                               NaN
# ...                                      ...
# 2022-12-27                          11.72720
# 2022-12-28                          11.72520
# 2022-12-29                          11.75830
# 2022-12-30                          11.72930
# 2022-12-31                               NaN
#
#            Aditya Birla Sun Life Mutual Fund  \
# ...

# %%
Nifty_final_extraction.to_csv("Nifty_f_w_cols.csv")

# %%
bench_mark.set_index('Date', inplace=True)
bench_mark.drop(['Open','High','Low','Volume','Turnover'], axis=1, inplace=True)
bench_mark
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 bench_mark.set_index('Date', inplace=True)
#       2 bench_mark.drop(['Open','High','Low','Volume','Turnover'], axis=1, inplace=True)
#       3 bench_mark
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# ...

# %%
bench_mark.drop(['Open','High','Low','Volume','Turnover'], axis=1, inplace=True)
bench_mark
# Out:
#                Close
# Date
# 2017-11-01  10440.50
# 2017-11-02  10423.80
# 2017-11-03  10452.50
# 2017-11-06  10451.80
# 2017-11-07  10350.15
# ...              ...
# 2022-12-23  17806.80
# 2022-12-26  18014.60
# 2022-12-27  18132.30
# 2022-12-28  18122.50
# 2022-12-29  18191.00
#
# [3631 rows x 1 columns]

# %%
bench_mark.to_csv("bench_mark.csv")

# %%
Nifty_final_extraction.apply(lambda x:x.drop([i], axis=1, inplace=True) if i not in nifty_schemecode)
# Out:
#   Input In [12]
#     Nifty_final_extraction.apply(lambda x:x.drop([i], axis=1, inplace=True) if i not in nifty_schemecode)
#                                                                                                         ^
# SyntaxError: invalid syntax

# %%
Nifty_final_extraction

# %%
Niftyindex[Niftyindex['scheme_code']==151165]['fund_house']
# Out:
# 3309    IIFL Mutual Fund
# Name: fund_house, dtype: object

# %%
cnt = 0
for i in Nifty_final_extraction.columns.tolist():
    if (i in nifty_schemecode) and (cnt <= Niftyindex['fund_house'].nunique()):
        nifty50_final_part1 = Nifty_final_extraction.rename(columns = {i:Niftyindex['fund_house']})
        cnt += 1
    elif (i in nifty_schemecode) and ((Niftyindex['fund_house'].nunique()) <= cnt <= (2*Niftyindex['fund_house'].nunique())):
        nifty50_final_part2 = Nifty_final_extraction.rename(columns = {i:Niftyindex['fund_house']})
        cnt += 1
    
    elif (i in nifty_schemecode) and ((2*Niftyindex['fund_house'].nunique()) <= cnt <= (3*Niftyindex['fund_house'].nunique())):
        nifty50_final_part3 = Nifty_final_extraction.rename(columns = {i:Niftyindex['fund_house']})
        cnt += 1
        
    elif (i in nifty_schemecode) and ((3*Niftyindex['fund_house'].nunique()) <= cnt <= (4*Niftyindex['fund_house'].nunique())):
        nifty50_final_part4 = Nifty_final_extraction.rename(columns = {i:Niftyindex['fund_house']})
        cnt += 1
    else:
        nifty50_final_part1.drop([i], axis=1)
        nifty50_final_part2.drop([i], axis=1)
        nifty50_final_part3.drop([i], axis=1)
        nifty50_final_part4.drop([i], axis=1)
        
        continue
        
print(cnt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#      16     cnt += 1
#      17 else:
# ---> 18     nifty50_final_part1.drop([i], axis=1)
#      19     nifty50_final_part2.drop([i], axis=1)
#      20     nifty50_final_part3.drop([i], axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
nifty50_final_part1
# Out:
#                119551     119552     119553     108272     110282     108274  \
# 23-01-2023  108.98030  113.92040  111.38510  163.36420  110.77260  108.41360
# 20-01-2023  108.93350  113.87150  111.33720  163.29870  110.72820  108.37010
# 19-01-2023  108.95780  113.89690  111.36210  163.33670  110.75400  108.39530
# 18-01-2023  108.92900  113.86680  111.33260  163.29510  110.72580  108.36770
# 17-01-2023  108.90980  113.84670  111.31310  163.26790  110.70740  108.34970
# ...               ...        ...        ...        ...        ...        ...
# 26-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 19-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 12-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 05-01-2019        NaN        NaN        NaN        NaN        NaN        NaN
# 16-11-2019        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
Niftyindex.dtypes
# Out:
# Unnamed: 0           int64
# fund_house          object
# scheme_type         object
# scheme_category     object
# scheme_code          int64
# scheme_name         object
# date                object
# nav                float64
# dtype: object
